# %%
#Q2.2.1
print(2.7/2)
print(2//4 -1 )
print(2/4 -1 )
print((2+5) % 3)
print(2 + 5 % 3)
print(3*4 //6)
print(3*(4 //6))
print(3** 2* 2)
# Out:
# 1.35
# -1
# -0.5
# 1
# 4
# 2
# 0
# 18

# %%
#Q2.2.2
print(-2 ** 2)
print(2 ** -2)
print(-2 ** -2)
print(2 ** 2 ** 3)
print(2 ** 3 ** 2) 
print(-2 ** 3 ** 2)
print((-2) ** 3 ** 2)
print((-2) ** 2 ** 3)
# Out:
# -4
# 0.25
# -0.25
# 256
# 512
# -512
# -512
# 256

# %%
#Q2.2.3
import math
from math import *
print(9+6j/2)
round(2.5)
round(-2.5)
abs(complex (3,4))==math.hypot(3,4)
# Out:
# (9+3j)
# True

# %%
#Q2.2.4
z= 1j
y= z**z
print(y)
# Out:
# (0.20787957635076193+0j)

# %%
#Q2.2.6
print(7 // 4)
print(7 % 4)
print(-7 // 4)
print(-7 % 4)
print(7 // -4)
print(7 % -4)
print(-7 // -4)
print(-7 % -4)
# Out:
# 1
# 3
# -2
# 1
# -2
# -1
# 1
# -3

# %%
#Q2.2.7
dado = lambda a,b : 3 * (a**3 * b - a*b**3) % 7
print(dado (2, 6))
print(dado (3, 5))
# Out:
# 3
# 1

# %%
#Q2.2.8
t=0.1/1000
d=384000*1000
print(d/t)
print(log(d/t, 2))
# Out:
# 3840000000000.0
# 41.80424344959478

# %%
#Q2.2.9
not 1<2 or 4>2
not (1<2 or 4>2)
1<2 or 4>2
4>2 or 10/0 == 0
not 0 < 1
1 and 2
0 and 1
1 or 0 
type(complex(2, 3).real) is int
# Out:
# False
